# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('merged_data_inner.csv')
df.head()
# Out:
#        Country  Year  AverageTemperature Code  \
# 0  Afghanistan  1850           13.185427  AFG
# 1  Afghanistan  1851           13.391073  AFG
# 2  Afghanistan  1852           13.337948  AFG
# 3  Afghanistan  1853           13.270833  AFG
# 4  Afghanistan  1854           13.481042  AFG
#
#    Annual nitrous oxide emissions in CO₂ equivalents  \
# 0                                          223008.40
# 1                                          227659.61
# 2                                          232190.92
# 3                                          236528.19
# 4                                          240597.22
#
#    Annual methane emissions in CO₂ equivalents  Annual CO₂ emissions
# 0                                    3594926.5             3520884.0
# 1                                    3615134.5             3561188.2
# 2                                    3635346.8             3596619.0
# 3                                    3655563.5             3630340.0
# ...

# %%
df.drop(['Code'], axis=1, inplace=True)

# %%
df.head()
# Out:
#        Country  Year  AverageTemperature  \
# 0  Afghanistan  1850           13.185427
# 1  Afghanistan  1851           13.391073
# 2  Afghanistan  1852           13.337948
# 3  Afghanistan  1853           13.270833
# 4  Afghanistan  1854           13.481042
#
#    Annual nitrous oxide emissions in CO₂ equivalents  \
# 0                                          223008.40
# 1                                          227659.61
# 2                                          232190.92
# 3                                          236528.19
# 4                                          240597.22
#
#    Annual methane emissions in CO₂ equivalents  Annual CO₂ emissions
# 0                                    3594926.5             3520884.0
# 1                                    3615134.5             3561188.2
# 2                                    3635346.8             3596619.0
# 3                                    3655563.5             3630340.0
# ...

# %%
# read the data using Date as index column
df_new = pd.read_csv('./merged_data_inner.csv', index_col='Year')

# %%
df_new.head()
# Out:
#           Country  AverageTemperature Code  \
# Year
# 1850  Afghanistan           13.185427  AFG
# 1851  Afghanistan           13.391073  AFG
# 1852  Afghanistan           13.337948  AFG
# 1853  Afghanistan           13.270833  AFG
# 1854  Afghanistan           13.481042  AFG
#
#       Annual nitrous oxide emissions in CO₂ equivalents  \
# Year
# 1850                                          223008.40
# 1851                                          227659.61
# 1852                                          232190.92
# 1853                                          236528.19
# 1854                                          240597.22
#
#       Annual methane emissions in CO₂ equivalents  Annual CO₂ emissions
# Year
# 1850                                    3594926.5             3520884.0
# 1851                                    3615134.5             3561188.2
# 1852                                    3635346.8             3596619.0
# ...

# %%
data_NO2 = df_new['Annual nitrous oxide emissions in CO₂ equivalents']
data_NO2
# Out:
# Year
# 1850     223008.40
# 1851     227659.61
# 1852     232190.92
# 1853     236528.19
# 1854     240597.22
#            ...
# 2009    5801720.50
# 2010    6143349.00
# 2011    6285581.00
# 2012    5845067.00
# 2013    5606479.00
# Name: Annual nitrous oxide emissions in CO₂ equivalents, Length: 24248, dtype: float64

# %%
data_NO2.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
# draw a non-linear trend
data_NO2.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data_NO2.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_CH4 = df_new['Annual methane emissions in CO₂ equivalents']
data_CH4
# Out:
# Year
# 1850     3594926.5
# 1851     3615134.5
# 1852     3635346.8
# 1853     3655563.5
# 1854     3675785.0
#            ...
# 2009    12969491.0
# 2010    13484060.0
# 2011    13840859.0
# 2012    13644580.0
# 2013    13450334.0
# Name: Annual methane emissions in CO₂ equivalents, Length: 24248, dtype: float64

# %%
data_CH4.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_CH4.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
# import pandas as pd

# # Load the dataset
# file_path = 'path_to_your_file/merged_data_inner.csv'  # Replace with your file path
# data = pd.read_csv(file_path)

# Extract data for India
india_data = df_new[df_new['Country'] == 'India']

# Save the extracted data to a new CSV file
india_data.to_csv('india_data.csv', index=False)

print("India's data has been successfully extracted and saved to 'india_data.csv'.")
# Out:
# India's data has been successfully extracted and saved to 'india_data.csv'.

# %%
india_data
# Out:
#      Country  AverageTemperature Code  \
# Year
# 1850   India           25.020840  IND
# 1851   India           24.989309  IND
# 1852   India           24.870223  IND
# 1853   India           25.171149  IND
# 1854   India           25.249421  IND
# ...      ...                 ...  ...
# 2009   India           26.603119  IND
# 2010   India           26.549878  IND
# 2011   India           25.880499  IND
# 2012   India           26.191226  IND
# 2013   India           26.864186  IND
#
#       Annual nitrous oxide emissions in CO₂ equivalents  \
# Year
# 1850                                         20569696.0
# 1851                                         20984666.0
# 1852                                         21389268.0
# 1853                                         21777102.0
# 1854                                         22141748.0
# ...                                                 ...
# 2009                                        229390700.0
# ...

# %%
india_data['Annual CO₂ emissions'].plot()
# Out:
# <Axes: xlabel='Year'>

# %%
india_data['AverageTemperature'].plot()
# Out:
# <Axes: xlabel='Year'>

# %%
india_data_CO2 = df['Annual CO₂ emissions']
india_data_CO2
# Out:
# 0         3520884.0
# 1         3561188.2
# 2         3596619.0
# 3         3630340.0
# 4         3662827.5
#             ...
# 24243    25019444.0
# 24244    29073518.0
# 24245    25961384.0
# 24246    23363448.0
# 24247    23313368.0
# Name: Annual CO₂ emissions, Length: 24248, dtype: float64

# %%
# draw a non-linear trend
india_data_CO2.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
india_data_CO2.plot(kind='box')
# Out:
# <Axes: >

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# get the seasonal decomposision
result = seasonal_decompose(india_data_CO2, period=5000)
result.plot()
